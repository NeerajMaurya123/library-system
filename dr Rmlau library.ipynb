# %%
from tkinter import *
from tkinter import ttk
class library:
    def __init__(self, root):
        self.root=root
        self.root.geometry("1350x1250")
        self.root.config(bg="silver")
        frame=Frame(self.root,bg='silver')
        frame.grid()
        lbl_title=Label(self.root,width=185, bd=10,bg='lime',relief=GROOVE,pady=20)
        lbl_title.place(x=20,y=10)
        Name=Label(self.root, font=('new times roman',20,'bold'),fg="red", bg="lime", text="\tDr.Ram Manohar Lohia Avadh University Ayodhya Digital Library System ").place(x=30,y=30)
        
        dataframe=Label(self.root,width=100,height=23,relief=RIDGE,bd=15,bg='navajowhite').place(x=20,y=85)
        dataframe=Label(dataframe,text='Member Type:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=105) 
        
        dataframe1=Label(self.root,width=80,height=23,relief=RIDGE,bd=15,bg='navajowhite').place(x=750,y=85)
        dataframe1=Label(dataframe1,text='Book Details:',font=('arial',15,'bold'),bg='navajowhite').place(x=770,y=105)
                
        dataframe2=Label(self.root,width=184,height=10,relief=GROOVE,bd=15,bg='white').place(x=20,y=465)
        
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=107)
        
        dataframe=Label(dataframe,text='Rfrence No:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=145) 
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=145)
        
        dataframe=Label(dataframe,text='Student Name:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=180)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=180)
        
        dataframe=Label(dataframe,text='Father Name:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=215)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=215)
        dataframe=Label(dataframe,text='Address:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=253)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=253)
        dataframe=Label(dataframe,text='Mobile No:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=290)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=290)
        dataframe=Label(dataframe,text='Book Id:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=328)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=328)
        dataframe=Label(dataframe,text='Book Title:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=367)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=367)
        dataframe=Label(dataframe,text='Author Name:',font=('arial',15,'bold'),bg='navajowhite').place(x=35,y=410)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=180,y=410)
        dataframe=Label(dataframe,text='Borrow Date:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=105)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=105)
        dataframe=Label(dataframe,text='Date Due:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=145)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=145)
        dataframe=Label(dataframe,text='Entry Time:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=190)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=190)
        dataframe=Label(dataframe,text='Course\n Name:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=230)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=245)
        dataframe=Label(dataframe,text='Id Card No:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=290)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=290)
        dataframe=Label(dataframe,text='Borrow No\nof\nBook:',font=('arial',15,'bold'),bg='navajowhite').place(x=395,y=330)
        e=Entry(dataframe,width=20,bd=5,font=('arial')).place(x=525,y=360)
        btn=Button(self.root,width=8,bd=8,text='save',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='blue').place(x=90,y=650) 
        btn=Button(self.root,width=10,bd=8,text='Update',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='green').place(x=225,y=650)
        btn=Button(self.root,width=8,bd=8,text='Reset',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='gold').place(x=390,y=650)
        btn=Button(self.root,width=8,bd=8,text='Delete',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='lime').place(x=520,y=650)
        btn=Button(self.root,width=8,bd=8,text='Display',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='blue').place(x=655,y=650)
        btn=Button(self.root,width=8,bd=8,text='Search',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='blue').place(x=790,y=652)
        btn=Button(self.root,width=8,bd=8,text='Exit',relief=GROOVE,font=('arial',15,'bold'),bg='red',activebackground='blue').place(x=930,y=652)
        
        lbl_title=Frame(root,height=350,relief=GROOVE, bd=0,bg='black')
        lbl_title.place(x=920,y=95)
if __name__ == '__main__':
       root = Tk()
       applicaton = library(root)
       root.mainloop()
